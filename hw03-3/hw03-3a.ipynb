# %% [markdown]
# <a href="https://colab.research.google.com/github/HuangJin-De/Machine-Learning-in-Atmospheric-Thermodynamics/blob/master/hw03-3/hw03-3a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! rm -rf Machine-Learning-in-Atmospheric-Thermodynamics
! git clone https://github.com/HuangJin-De/Machine-Learning-in-Atmospheric-Thermodynamics.git
# Out:
# Cloning into 'Machine-Learning-in-Atmospheric-Thermodynamics'...
# remote: Enumerating objects: 466, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 466 (delta 16), reused 10 (delta 2), pack-reused 430
# Receiving objects: 100% (466/466), 186.10 MiB | 16.17 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler  
from sklearn.model_selection import train_test_split

path='Machine-Learning-in-Atmospheric-Thermodynamics/hw03-3'
filen=path+'/data/era5_stn_thl_thl.dat'

data=np.fromfile(filen,dtype=np.float32)
data=data.reshape(-1,33)

x=data[:,0:32]
y=data[:,32].reshape(-1,1)#.astype(int)

print(x.shape,x[1,:])
print(y.shape,y[1,:])

x_temp,x_valid,y_temp,y_valid=train_test_split(x,y,test_size=0.2,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x_temp,y_temp,test_size=0.2,random_state=1)

label_unique, counts=np.unique(y_temp,return_counts=True)
print(label_unique, counts)
weight=[sum(counts)/c for c in counts]
print(weight)

x_temp=x_temp.reshape(-1,2,16)
x_train=x_train.reshape(-1,2,16)
x_test=x_test.reshape(-1,2,16)
x_valid=x_valid.reshape(-1,2,16)

scaler=[]
scaler.append(MinMaxScaler())
scaler.append(MinMaxScaler())

for i in range(0,2):
  x_temp[:,i,:]=scaler[i].fit_transform(x_temp[:,i,:])
  x_train[:,i,:]=scaler[i].transform(x_train[:,i,:])
  x_test[:,i,:]=scaler[i].transform(x_test[:,i,:])
  x_valid[:,i,:]=scaler[i].transform(x_valid[:,i,:])
  
x_temp=x_temp.reshape(-1,32)
x_train=x_train.reshape(-1,32)
x_test=x_test.reshape(-1,32)
x_valid=x_valid.reshape(-1,32)

print('finished')
# Out:
# (9417, 32) [326.3718  323.53485 320.28345 317.47916 315.2194  312.18768 310.70334
#  309.30786 307.9837  306.47418 305.0847  303.90884 302.8444  301.75427
#  300.1606  299.98868 326.3718  323.53485 320.28345 317.47916 315.2194
#  312.18768 310.70334 309.30786 307.9837  306.47418 305.0847  303.90884
#  302.8444  301.75427 300.1606  299.98868]
# (9417, 1) [0.]
# [0. 1.] [2130 5403]
# [3.536619718309859, 1.394225430316491]
# finished

# %%
import torch
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

class TrainData(Dataset):
    
    def __init__(self, x_data, y_data):
        self.x_data = x_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.x_data)

train_data=TrainData(torch.FloatTensor(x_train),torch.FloatTensor(y_train))
test_data=TrainData(torch.FloatTensor(x_test),torch.FloatTensor(y_test))
valid_data=TrainData(torch.FloatTensor(x_valid),torch.FloatTensor(y_valid))

BATCH_SIZE=64
weight_train=[weight[k] for k in y_train.reshape(-1).astype(int)]
sampler_train=WeightedRandomSampler(weight_train,len(y_train))
train_loader=DataLoader(dataset=train_data,sampler=sampler_train,batch_size=BATCH_SIZE)

weight_test=[weight[k] for k in y_test.reshape(-1).astype(int)]
sampler_test=WeightedRandomSampler(weight_test,len(y_test))
test_loader=DataLoader(dataset=test_data,sampler=sampler_test,batch_size=BATCH_SIZE)

valid_loader=DataLoader(dataset=valid_data,batch_size=1)

print('finished')
# Out:
# finished

# %%
from torch import nn
from torchvision.transforms import ToTensor, Lambda, Compose
import time

class BinaryClassification(nn.Module):
  def __init__(self):
    super(BinaryClassification, self).__init__()
    self.BC = nn.Sequential(
      nn.Linear(32, 256),   
      nn.ReLU(),     
      nn.BatchNorm1d(256),   
      nn.Linear(256, 192),
      nn.ReLU(),
      nn.BatchNorm1d(192),
      nn.Dropout(p=0.1),
      nn.Linear(192, 1)
    )

  def forward(self, x):
    freq = self.BC(x)
    binary = freq #torch.round(freq)
    return binary

print('defined model')
# Out:
# defined model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = BinaryClassification().to(device)

loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)

    model.train()
    train_loss=0

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        pred = model(X)  
        loss = loss_fn(pred, y) 
        train_loss += loss.item()

        optimizer.zero_grad()  
        loss.backward()      
        optimizer.step()      
       
        #if batch % 100 == 0:
        #    loss, current = loss.item(), batch * len(X)
        #    print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    train_loss /= num_batches
    return train_loss

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)

    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0

    with torch.no_grad(): 
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)

            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (torch.round(torch.sigmoid(pred))==y).sum().float()

    test_loss /= num_batches
    correct /= size
    print(f"Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}")
    return test_loss

# training start
epochs=150

tt=time.time()
train_loss=[]
test_loss=[]
for t in range(epochs):
    print(f"Epoch {t+1}-------------------------------")
    loss = train(train_loader, model, loss_fn, optimizer)
    train_loss.append(loss)
    loss = test(test_loader, model, loss_fn)
    test_loss.append(loss)

elapse=time.time()-tt
print(elapse)

torch.save(model.state_dict(),'model.pkl')
# Out:
# Epoch 1-------------------------------
# Accuracy: 66.8%, Avg loss: 0.616201
# Epoch 2-------------------------------
# Accuracy: 70.7%, Avg loss: 0.588140
# Epoch 3-------------------------------
# Accuracy: 74.3%, Avg loss: 0.544636
# Epoch 4-------------------------------
# Accuracy: 72.6%, Avg loss: 0.550326
# Epoch 5-------------------------------
# Accuracy: 75.0%, Avg loss: 0.526599
# Epoch 6-------------------------------
# Accuracy: 77.2%, Avg loss: 0.501954
# Epoch 7-------------------------------
# Accuracy: 75.0%, Avg loss: 0.514774
# Epoch 8-------------------------------
# Accuracy: 75.4%, Avg loss: 0.516858
# Epoch 9-------------------------------
# Accuracy: 76.7%, Avg loss: 0.508605
# Epoch 10-------------------------------
# Accuracy: 76.8%, Avg loss: 0.494260
# Epoch 11-------------------------------
# Accuracy: 76.4%, Avg loss: 0.501566
# Epoch 12-------------------------------
# Accuracy: 75.9%, Avg loss: 0.501914
# Epoch 13-------------------------------
# Accuracy: 76.8%, Avg loss: 0.498817
# Epoch 14-------------------------------
# Accuracy: 75.0%, Avg loss: 0.497484
# Epoch 15-------------------------------
# Accuracy: 75.6%, Avg loss: 0.505020
# Epoch 16-------------------------------
# Accuracy: 76.5%, Avg loss: 0.489636
# Epoch 17-------------------------------
# Accuracy: 75.7%, Avg loss: 0.499048
# Epoch 18-------------------------------
# Accuracy: 75.6%, Avg loss: 0.515714
# Epoch 19-------------------------------
# Accuracy: 77.8%, Avg loss: 0.481165
# Epoch 20-------------------------------
# Accuracy: 76.8%, Avg loss: 0.492453
# Epoch 21-------------------------------
# Accuracy: 75.1%, Avg loss: 0.500373
# Epoch 22-------------------------------
# Accuracy: 76.6%, Avg loss: 0.493373
# Epoch 23-------------------------------
# Accuracy: 76.3%, Avg loss: 0.490050
# Epoch 24-------------------------------
# Accuracy: 78.9%, Avg loss: 0.477461
# Epoch 25-------------------------------
# Accuracy: 75.6%, Avg loss: 0.508551
# Epoch 26-------------------------------
# Accuracy: 76.2%, Avg loss: 0.507318
# Epoch 27-------------------------------
# Accuracy: 78.4%, Avg loss: 0.484395
# Epoch 28-------------------------------
# Accuracy: 77.1%, Avg loss: 0.489539
# Epoch 29-------------------------------
# Accuracy: 76.3%, Avg loss: 0.490146
# Epoch 30-------------------------------
# Accuracy: 76.0%, Avg loss: 0.498288
# Epoch 31-------------------------------
# Accuracy: 76.4%, Avg loss: 0.500602
# Epoch 32-------------------------------
# Accuracy: 75.8%, Avg loss: 0.495139
# Epoch 33-------------------------------
# Accuracy: 76.9%, Avg loss: 0.479280
# Epoch 34-------------------------------
# Accuracy: 76.6%, Avg loss: 0.503890
# Epoch 35-------------------------------
# Accuracy: 75.8%, Avg loss: 0.499622
# Epoch 36-------------------------------
# Accuracy: 75.3%, Avg loss: 0.500472
# Epoch 37-------------------------------
# Accuracy: 76.7%, Avg loss: 0.485422
# Epoch 38-------------------------------
# Accuracy: 78.4%, Avg loss: 0.473331
# Epoch 39-------------------------------
# Accuracy: 73.1%, Avg loss: 0.528302
# Epoch 40-------------------------------
# Accuracy: 77.2%, Avg loss: 0.482267
# Epoch 41-------------------------------
# Accuracy: 75.0%, Avg loss: 0.499060
# Epoch 42-------------------------------
# Accuracy: 76.8%, Avg loss: 0.495666
# Epoch 43-------------------------------
# Accuracy: 74.8%, Avg loss: 0.500821
# Epoch 44-------------------------------
# Accuracy: 76.7%, Avg loss: 0.497552
# Epoch 45-------------------------------
# Accuracy: 78.5%, Avg loss: 0.478413
# Epoch 46-------------------------------
# Accuracy: 74.7%, Avg loss: 0.513964
# Epoch 47-------------------------------
# Accuracy: 75.7%, Avg loss: 0.504055
# Epoch 48-------------------------------
# Accuracy: 76.1%, Avg loss: 0.494331
# Epoch 49-------------------------------
# Accuracy: 77.2%, Avg loss: 0.481793
# Epoch 50-------------------------------
# Accuracy: 76.2%, Avg loss: 0.496817
# Epoch 51-------------------------------
# Accuracy: 76.6%, Avg loss: 0.490558
# Epoch 52-------------------------------
# Accuracy: 75.9%, Avg loss: 0.495097
# Epoch 53-------------------------------
# Accuracy: 77.1%, Avg loss: 0.480187
# Epoch 54-------------------------------
# Accuracy: 76.8%, Avg loss: 0.493215
# Epoch 55-------------------------------
# Accuracy: 76.2%, Avg loss: 0.506990
# Epoch 56-------------------------------
# Accuracy: 75.6%, Avg loss: 0.486418
# Epoch 57-------------------------------
# Accuracy: 77.6%, Avg loss: 0.482671
# Epoch 58-------------------------------
# Accuracy: 75.7%, Avg loss: 0.491319
# Epoch 59-------------------------------
# Accuracy: 75.6%, Avg loss: 0.498745
# Epoch 60-------------------------------
# Accuracy: 77.2%, Avg loss: 0.490225
# Epoch 61-------------------------------
# Accuracy: 74.5%, Avg loss: 0.509781
# Epoch 62-------------------------------
# Accuracy: 76.0%, Avg loss: 0.490761
# Epoch 63-------------------------------
# Accuracy: 77.6%, Avg loss: 0.473028
# Epoch 64-------------------------------
# Accuracy: 76.0%, Avg loss: 0.478936
# Epoch 65-------------------------------
# Accuracy: 78.0%, Avg loss: 0.485023
# Epoch 66-------------------------------
# Accuracy: 77.0%, Avg loss: 0.473684
# Epoch 67-------------------------------
# Accuracy: 75.8%, Avg loss: 0.486678
# Epoch 68-------------------------------
# Accuracy: 75.9%, Avg loss: 0.493030
# Epoch 69-------------------------------
# Accuracy: 75.2%, Avg loss: 0.509345
# Epoch 70-------------------------------
# Accuracy: 76.3%, Avg loss: 0.493934
# Epoch 71-------------------------------
# Accuracy: 75.6%, Avg loss: 0.487081
# Epoch 72-------------------------------
# Accuracy: 75.6%, Avg loss: 0.482457
# Epoch 73-------------------------------
# Accuracy: 76.6%, Avg loss: 0.482102
# Epoch 74-------------------------------
# Accuracy: 78.0%, Avg loss: 0.457510
# Epoch 75-------------------------------
# Accuracy: 77.9%, Avg loss: 0.490758
# Epoch 76-------------------------------
# Accuracy: 74.9%, Avg loss: 0.507408
# Epoch 77-------------------------------
# Accuracy: 77.8%, Avg loss: 0.470188
# Epoch 78-------------------------------
# Accuracy: 78.2%, Avg loss: 0.474558
# Epoch 79-------------------------------
# Accuracy: 76.4%, Avg loss: 0.484450
# Epoch 80-------------------------------
# Accuracy: 76.6%, Avg loss: 0.488796
# Epoch 81-------------------------------
# Accuracy: 77.5%, Avg loss: 0.465447
# Epoch 82-------------------------------
# Accuracy: 79.2%, Avg loss: 0.468310
# Epoch 83-------------------------------
# Accuracy: 75.0%, Avg loss: 0.487054
# Epoch 84-------------------------------
# Accuracy: 75.5%, Avg loss: 0.495483
# Epoch 85-------------------------------
# Accuracy: 75.6%, Avg loss: 0.502017
# Epoch 86-------------------------------
# Accuracy: 77.7%, Avg loss: 0.477956
# Epoch 87-------------------------------
# Accuracy: 76.2%, Avg loss: 0.496461
# Epoch 88-------------------------------
# Accuracy: 77.4%, Avg loss: 0.480301
# Epoch 89-------------------------------
# Accuracy: 76.6%, Avg loss: 0.490039
# Epoch 90-------------------------------
# Accuracy: 76.5%, Avg loss: 0.504760
# Epoch 91-------------------------------
# Accuracy: 77.7%, Avg loss: 0.477210
# Epoch 92-------------------------------
# Accuracy: 77.2%, Avg loss: 0.488593
# Epoch 93-------------------------------
# Accuracy: 75.2%, Avg loss: 0.496280
# Epoch 94-------------------------------
# Accuracy: 75.5%, Avg loss: 0.499421
# Epoch 95-------------------------------
# Accuracy: 76.0%, Avg loss: 0.484210
# Epoch 96-------------------------------
# Accuracy: 78.6%, Avg loss: 0.469161
# Epoch 97-------------------------------
# Accuracy: 77.2%, Avg loss: 0.474653
# Epoch 98-------------------------------
# Accuracy: 76.2%, Avg loss: 0.490417
# Epoch 99-------------------------------
# Accuracy: 78.1%, Avg loss: 0.470708
# Epoch 100-------------------------------
# Accuracy: 75.6%, Avg loss: 0.505557
# Epoch 101-------------------------------
# Accuracy: 74.9%, Avg loss: 0.493611
# Epoch 102-------------------------------
# Accuracy: 77.0%, Avg loss: 0.485941
# Epoch 103-------------------------------
# Accuracy: 75.4%, Avg loss: 0.508559
# Epoch 104-------------------------------
# Accuracy: 76.6%, Avg loss: 0.500067
# Epoch 105-------------------------------
# Accuracy: 76.3%, Avg loss: 0.483214
# Epoch 106-------------------------------
# Accuracy: 77.0%, Avg loss: 0.484834
# Epoch 107-------------------------------
# Accuracy: 76.5%, Avg loss: 0.504915
# Epoch 108-------------------------------
# Accuracy: 75.4%, Avg loss: 0.504248
# Epoch 109-------------------------------
# Accuracy: 75.0%, Avg loss: 0.512881
# Epoch 110-------------------------------
# Accuracy: 75.8%, Avg loss: 0.504781
# Epoch 111-------------------------------
# Accuracy: 75.8%, Avg loss: 0.493268
# Epoch 112-------------------------------
# Accuracy: 76.4%, Avg loss: 0.501436
# Epoch 113-------------------------------
# Accuracy: 75.4%, Avg loss: 0.485026
# Epoch 114-------------------------------
# Accuracy: 76.0%, Avg loss: 0.489792
# Epoch 115-------------------------------
# Accuracy: 78.8%, Avg loss: 0.484324
# Epoch 116-------------------------------
# Accuracy: 76.4%, Avg loss: 0.493848
# Epoch 117-------------------------------
# Accuracy: 76.8%, Avg loss: 0.491379
# Epoch 118-------------------------------
# Accuracy: 77.0%, Avg loss: 0.482385
# Epoch 119-------------------------------
# Accuracy: 74.9%, Avg loss: 0.499604
# Epoch 120-------------------------------
# Accuracy: 78.2%, Avg loss: 0.481227
# Epoch 121-------------------------------
# Accuracy: 75.4%, Avg loss: 0.499803
# Epoch 122-------------------------------
# Accuracy: 76.2%, Avg loss: 0.499141
# Epoch 123-------------------------------
# Accuracy: 76.6%, Avg loss: 0.478101
# Epoch 124-------------------------------
# Accuracy: 78.1%, Avg loss: 0.472298
# Epoch 125-------------------------------
# Accuracy: 76.7%, Avg loss: 0.499443
# Epoch 126-------------------------------
# Accuracy: 76.5%, Avg loss: 0.475223
# Epoch 127-------------------------------
# Accuracy: 77.2%, Avg loss: 0.492165
# Epoch 128-------------------------------
# Accuracy: 76.9%, Avg loss: 0.482397
# Epoch 129-------------------------------
# Accuracy: 75.1%, Avg loss: 0.512969
# Epoch 130-------------------------------
# Accuracy: 78.6%, Avg loss: 0.462981
# Epoch 131-------------------------------
# Accuracy: 75.2%, Avg loss: 0.484950
# Epoch 132-------------------------------
# Accuracy: 74.5%, Avg loss: 0.512876
# Epoch 133-------------------------------
# Accuracy: 77.6%, Avg loss: 0.476117
# Epoch 134-------------------------------
# Accuracy: 76.6%, Avg loss: 0.490586
# Epoch 135-------------------------------
# Accuracy: 76.4%, Avg loss: 0.495569
# Epoch 136-------------------------------
# Accuracy: 75.1%, Avg loss: 0.491857
# Epoch 137-------------------------------
# Accuracy: 76.0%, Avg loss: 0.501244
# Epoch 138-------------------------------
# Accuracy: 76.7%, Avg loss: 0.471135
# Epoch 139-------------------------------
# Accuracy: 75.8%, Avg loss: 0.499910
# Epoch 140-------------------------------
# Accuracy: 76.2%, Avg loss: 0.489414
# Epoch 141-------------------------------
# Accuracy: 77.4%, Avg loss: 0.474542
# Epoch 142-------------------------------
# Accuracy: 76.8%, Avg loss: 0.494267
# Epoch 143-------------------------------
# Accuracy: 75.4%, Avg loss: 0.497048
# Epoch 144-------------------------------
# Accuracy: 75.8%, Avg loss: 0.498329
# Epoch 145-------------------------------
# Accuracy: 76.3%, Avg loss: 0.494498
# Epoch 146-------------------------------
# Accuracy: 76.0%, Avg loss: 0.491198
# Epoch 147-------------------------------
# Accuracy: 77.0%, Avg loss: 0.478491
# Epoch 148-------------------------------
# Accuracy: 74.6%, Avg loss: 0.495844
# Epoch 149-------------------------------
# Accuracy: 78.3%, Avg loss: 0.463793
# Epoch 150-------------------------------
# Accuracy: 77.9%, Avg loss: 0.463119
# 52.76494860649109

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(np.arange(1,epochs+1),train_loss,'b',np.arange(1,epochs+1),test_loss,'r')
plt.legend(["training loss","test loss"])

# %%
import seaborn as sn

model2 = BinaryClassification()
model2.load_state_dict(torch.load('model.pkl'))

classes = [
    "No Inv",
    "Inv"
]

model2.eval()

cm=np.zeros((len(classes),len(classes)))

#test_loader=DataLoader(test_data,sampler=sampler_test,batch_size=1)
xa=[]
xb=[]
xc=[]
xd=[]
for x,y in valid_loader:
  pred = model2(x)
  pred = torch.round(torch.sigmoid(pred))
  x1=pred.detach().numpy().astype(int)
  y1=y.detach().numpy().astype(int)
  cm[x1,y1]+=1
  #print(f'預測值："{pred[0].argmax(0)}" / 實際值："{y[0]}"')

  for n in range(0,y1.shape[0]):
    if x1[n]==y1[n] & y1[n]==0:
      xa.append(x[n,:])
    if x1[n]!=y1[n] & y1[n]==0:
      xb.append(x[n,:])
    if x1[n]!=y1[n] & y1[n]==1:
      xc.append(x[n,:])
    if x1[n]==y1[n] & y1[n]==1:
      xd.append(x[n,:])

plt.rcParams.update({'ytick.major.size':2,'ytick.major.width':0.75})
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax=sn.heatmap(cm.transpose(),xticklabels=classes,yticklabels=classes,annot=True,cmap='Blues',fmt='g',annot_kws={"fontsize":4})

plt.yticks(rotation=0) 
plt.xticks(rotation=90)
sn.set(font_scale=0.5)
ax.tick_params(labelsize=4) 
ax.figure.axes[-1].tick_params(labelsize=4)
plt.xlabel('Prediction')
plt.ylabel('True')

print('\n\n\n\n\n\n\n')
print('Accuracy is ',np.diagonal(cm).sum()/cm.sum())
print('Precision is ',cm[1,1]/cm[1,:].sum())
print('Recall is ',cm[1,1]/cm[:,1].sum())
print('F1 score is ',2.*(cm[1,1]/cm[:,1].sum()*cm[1,1]/cm[1,:].sum())/(cm[1,1]/cm[:,1].sum()+cm[1,1]/cm[1,:].sum()))
# Out:
# Accuracy is  0.7399150743099787
# Precision is  0.9183874139626352
# Recall is  0.6964951528709918
# F1 score is  0.7921967769296014

# %%
print(len(xa),len(xb),len(xc),len(xd))
p=np.flip(np.array([1000.,975.,950.,925.,900.,875.,850.,825.,800.,775.,750.,700.,650.,600.,550.,500.]),0)
fig,ax=plt.subplots(nrows=4,ncols=2,figsize=(4,8),dpi=300)
ax=ax.flatten()

for i in range(0,8,2):
  print(i)
  ii=i*10+4
  if i==0:
    xdraw=scaler[0].inverse_transform(xa[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xa[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+12][16:32].reshape(-1,16)),0)
  if i==2:
    xdraw=scaler[0].inverse_transform(xb[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xb[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+12][16:32].reshape(-1,16)),0)
  if i==4:
    xdraw=scaler[0].inverse_transform(xc[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xc[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+12][16:32].reshape(-1,16)),0)
  if i==6:
    xdraw=scaler[0].inverse_transform(xd[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xd[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+12][16:32].reshape(-1,16)),0)
  
  ax[i].plot(xdraw[0,:],p,'b',xdraw[1,:],p,'r',xdraw[2,:],p,'y',xdraw[3,:],p,'k')
  ax[i].set_ylim([1000,500])
  ax[i].set_xlim([280,330])
  ax[i].set_xlabel('theta_l',fontsize=8)
  ax[i].set_ylabel('pressure',fontsize=8)

  ax[i+1].plot(xdraw2[0,:],p,'b',xdraw2[1,:],p,'r',xdraw2[2,:],p,'y',xdraw2[3,:],p,'k')
  ax[i+1].set_ylim([1000,500])
  ax[i+1].set_xlim([0.,0.02])
  ax[i+1].set_xlabel('Qt',fontsize=8)
# Out:
# 460 83 407 934
# 0
# 2
# 4
# 6

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

valid_loader=DataLoader(dataset=valid_data,batch_size=10000)
for x,y in valid_loader:
  print(x.shape,y.shape)
  pred = model2(x)
  pred = torch.sigmoid(pred)
  x1=pred.detach().numpy()
  y1=y.detach().numpy()

rocx,rocy,_=roc_curve(y1,x1)
roc_area=roc_auc_score(y1,x1)
print(roc_area)

fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(rocx,rocy,'r-',[0, 1],[0, 1],'b--')
ax.set_ylim([0,1])
ax.set_xlim([0,1])
ax.set_xlabel('False alarm rate',fontsize=8)
ax.set_ylabel('Hit rate',fontsize=8)
ax.grid(lw=0.5,alpha=0.5)
# Out:
# torch.Size([1884, 32]) torch.Size([1884, 1])
# 0.83301541001122
