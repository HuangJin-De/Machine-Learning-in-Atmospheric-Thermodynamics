# %% [markdown]
# <a href="https://colab.research.google.com/github/HuangJin-De/Machine-Learning-in-Atmospheric-Thermodynamics/blob/master/hw03-3/hw03-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! rm -rf Machine-Learning-in-Atmospheric-Thermodynamics
! git clone https://github.com/HuangJin-De/Machine-Learning-in-Atmospheric-Thermodynamics.git
# Out:
# Cloning into 'Machine-Learning-in-Atmospheric-Thermodynamics'...
# remote: Enumerating objects: 487, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 487 (delta 28), reused 18 (delta 8), pack-reused 430
# Receiving objects: 100% (487/487), 188.21 MiB | 41.47 MiB/s, done.
# Resolving deltas: 100% (186/186), done.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import StandardScaler, MinMaxScaler  
from sklearn.model_selection import train_test_split

path='Machine-Learning-in-Atmospheric-Thermodynamics/hw03-3'
filen=path+'/data/era5_stn_the_qt.dat'

data=np.fromfile(filen,dtype=np.float32)
data=data.reshape(-1,33)

x=data[:,0:32]
y=data[:,32].reshape(-1,1)#.astype(int)

print(x.shape,x[1,:])
print(y.shape,y[1,:])

x_temp,x_valid,y_temp,y_valid=train_test_split(x,y,test_size=0.2,random_state=1)
x_train,x_test,y_train,y_test=train_test_split(x_temp,y_temp,test_size=0.2,random_state=1)

label_unique, counts=np.unique(y_temp,return_counts=True)
print(label_unique, counts)
weight=[sum(counts)/c for c in counts]
print(weight)

x_temp=x_temp.reshape(-1,2,16)
x_train=x_train.reshape(-1,2,16)
x_test=x_test.reshape(-1,2,16)
x_valid=x_valid.reshape(-1,2,16)

scaler=[]
scaler.append(MinMaxScaler())
scaler.append(MinMaxScaler())

for i in range(0,2):
  x_temp[:,i,:]=scaler[i].fit_transform(x_temp[:,i,:])
  x_train[:,i,:]=scaler[i].transform(x_train[:,i,:])
  x_test[:,i,:]=scaler[i].transform(x_test[:,i,:])
  x_valid[:,i,:]=scaler[i].transform(x_valid[:,i,:])
  
x_temp=x_temp.reshape(-1,32)
x_train=x_train.reshape(-1,32)
x_test=x_test.reshape(-1,32)
x_valid=x_valid.reshape(-1,32)

print('finished')
# Out:
# (9417, 32) [3.3157935e+02 3.3074289e+02 3.3043533e+02 3.3191925e+02 3.3153165e+02
#  3.3508179e+02 3.3599237e+02 3.3638693e+02 3.3598370e+02 3.3686115e+02
#  3.3866953e+02 3.4046585e+02 3.4243167e+02 3.4510193e+02 3.5144693e+02
#  3.5237067e+02 1.7029390e-03 2.4146584e-03 3.4704253e-03 5.0168689e-03
#  5.7712728e-03 8.1767254e-03 9.0826387e-03 9.7859437e-03 1.0192133e-02
#  1.1113258e-02 1.2322761e-02 1.3459079e-02 1.4620035e-02 1.6037675e-02
#  1.8887158e-02 1.9398857e-02]
# (9417, 1) [0.]
# [0. 1.] [2130 5403]
# [3.536619718309859, 1.394225430316491]
# finished

# %%
import torch
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

class TrainData(Dataset):
    
    def __init__(self, x_data, y_data):
        self.x_data = x_data
        self.y_data = y_data
        
    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]
        
    def __len__ (self):
        return len(self.x_data)

train_data=TrainData(torch.FloatTensor(x_train),torch.FloatTensor(y_train))
test_data=TrainData(torch.FloatTensor(x_test),torch.FloatTensor(y_test))
valid_data=TrainData(torch.FloatTensor(x_valid),torch.FloatTensor(y_valid))

BATCH_SIZE=64
weight_train=[weight[k] for k in y_train.reshape(-1).astype(int)]
sampler_train=WeightedRandomSampler(weight_train,len(y_train))
train_loader=DataLoader(dataset=train_data,sampler=sampler_train,batch_size=BATCH_SIZE)

weight_test=[weight[k] for k in y_test.reshape(-1).astype(int)]
sampler_test=WeightedRandomSampler(weight_test,len(y_test))
test_loader=DataLoader(dataset=test_data,sampler=sampler_test,batch_size=BATCH_SIZE)

valid_loader=DataLoader(dataset=valid_data,batch_size=1)

print('finished')
# Out:
# finished

# %%
from torch import nn
from torchvision.transforms import ToTensor, Lambda, Compose
import time

class BinaryClassification(nn.Module):
  def __init__(self):
    super(BinaryClassification, self).__init__()
    self.BC = nn.Sequential(
      nn.Linear(32, 256),   
      nn.ReLU(),     
      nn.BatchNorm1d(256),   
      nn.Linear(256, 192),
      nn.ReLU(),
      nn.BatchNorm1d(192),
      nn.Dropout(p=0.1),
      nn.Linear(192, 1)
    )

  def forward(self, x):
    freq = self.BC(x)
    binary = freq #torch.round(freq)
    return binary

print('defined model')
# Out:
# defined model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = BinaryClassification().to(device)

loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)

    model.train()
    train_loss=0

    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        pred = model(X)  
        loss = loss_fn(pred, y) 
        train_loss += loss.item()

        optimizer.zero_grad()  
        loss.backward()      
        optimizer.step()      
       
        #if batch % 100 == 0:
        #    loss, current = loss.item(), batch * len(X)
        #    print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

    train_loss /= num_batches
    return train_loss

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)

    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0

    with torch.no_grad(): 
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)

            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (torch.round(torch.sigmoid(pred))==y).sum().float()

    test_loss /= num_batches
    correct /= size
    print(f"Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f}")
    return test_loss

# training start
epochs=150

tt=time.time()
train_loss=[]
test_loss=[]
for t in range(epochs):
    print(f"Epoch {t+1}-------------------------------")
    loss = train(train_loader, model, loss_fn, optimizer)
    train_loss.append(loss)
    loss = test(test_loader, model, loss_fn)
    test_loss.append(loss)

elapse=time.time()-tt
print(elapse)

torch.save(model.state_dict(),'model.pkl')
# Out:
# Epoch 1-------------------------------
# Accuracy: 69.6%, Avg loss: 0.588314
# Epoch 2-------------------------------
# Accuracy: 74.0%, Avg loss: 0.534434
# Epoch 3-------------------------------
# Accuracy: 75.4%, Avg loss: 0.525997
# Epoch 4-------------------------------
# Accuracy: 76.8%, Avg loss: 0.523024
# Epoch 5-------------------------------
# Accuracy: 75.4%, Avg loss: 0.497244
# Epoch 6-------------------------------
# Accuracy: 78.6%, Avg loss: 0.485195
# Epoch 7-------------------------------
# Accuracy: 78.5%, Avg loss: 0.493558
# Epoch 8-------------------------------
# Accuracy: 77.0%, Avg loss: 0.481926
# Epoch 9-------------------------------
# Accuracy: 78.8%, Avg loss: 0.475251
# Epoch 10-------------------------------
# Accuracy: 78.7%, Avg loss: 0.476368
# Epoch 11-------------------------------
# Accuracy: 77.0%, Avg loss: 0.487357
# Epoch 12-------------------------------
# Accuracy: 79.5%, Avg loss: 0.456970
# Epoch 13-------------------------------
# Accuracy: 74.9%, Avg loss: 0.505323
# Epoch 14-------------------------------
# Accuracy: 78.4%, Avg loss: 0.477831
# Epoch 15-------------------------------
# Accuracy: 78.4%, Avg loss: 0.463365
# Epoch 16-------------------------------
# Accuracy: 77.7%, Avg loss: 0.479585
# Epoch 17-------------------------------
# Accuracy: 79.7%, Avg loss: 0.454848
# Epoch 18-------------------------------
# Accuracy: 80.0%, Avg loss: 0.434537
# Epoch 19-------------------------------
# Accuracy: 79.3%, Avg loss: 0.444450
# Epoch 20-------------------------------
# Accuracy: 81.2%, Avg loss: 0.435441
# Epoch 21-------------------------------
# Accuracy: 79.5%, Avg loss: 0.448463
# Epoch 22-------------------------------
# Accuracy: 80.2%, Avg loss: 0.442173
# Epoch 23-------------------------------
# Accuracy: 79.9%, Avg loss: 0.453728
# Epoch 24-------------------------------
# Accuracy: 79.8%, Avg loss: 0.443216
# Epoch 25-------------------------------
# Accuracy: 80.1%, Avg loss: 0.467395
# Epoch 26-------------------------------
# Accuracy: 79.3%, Avg loss: 0.445299
# Epoch 27-------------------------------
# Accuracy: 79.8%, Avg loss: 0.449413
# Epoch 28-------------------------------
# Accuracy: 78.6%, Avg loss: 0.459690
# Epoch 29-------------------------------
# Accuracy: 78.1%, Avg loss: 0.456575
# Epoch 30-------------------------------
# Accuracy: 79.0%, Avg loss: 0.454325
# Epoch 31-------------------------------
# Accuracy: 78.7%, Avg loss: 0.445494
# Epoch 32-------------------------------
# Accuracy: 79.7%, Avg loss: 0.459866
# Epoch 33-------------------------------
# Accuracy: 80.8%, Avg loss: 0.438248
# Epoch 34-------------------------------
# Accuracy: 80.0%, Avg loss: 0.448250
# Epoch 35-------------------------------
# Accuracy: 79.7%, Avg loss: 0.450744
# Epoch 36-------------------------------
# Accuracy: 79.9%, Avg loss: 0.430965
# Epoch 37-------------------------------
# Accuracy: 79.6%, Avg loss: 0.448324
# Epoch 38-------------------------------
# Accuracy: 77.7%, Avg loss: 0.472990
# Epoch 39-------------------------------
# Accuracy: 79.2%, Avg loss: 0.469135
# Epoch 40-------------------------------
# Accuracy: 79.8%, Avg loss: 0.456342
# Epoch 41-------------------------------
# Accuracy: 78.7%, Avg loss: 0.460441
# Epoch 42-------------------------------
# Accuracy: 79.5%, Avg loss: 0.451219
# Epoch 43-------------------------------
# Accuracy: 79.6%, Avg loss: 0.435781
# Epoch 44-------------------------------
# Accuracy: 81.8%, Avg loss: 0.427717
# Epoch 45-------------------------------
# Accuracy: 81.0%, Avg loss: 0.427850
# Epoch 46-------------------------------
# Accuracy: 79.7%, Avg loss: 0.450686
# Epoch 47-------------------------------
# Accuracy: 79.3%, Avg loss: 0.458130
# Epoch 48-------------------------------
# Accuracy: 81.6%, Avg loss: 0.427393
# Epoch 49-------------------------------
# Accuracy: 81.6%, Avg loss: 0.423237
# Epoch 50-------------------------------
# Accuracy: 81.2%, Avg loss: 0.432774
# Epoch 51-------------------------------
# Accuracy: 79.6%, Avg loss: 0.457765
# Epoch 52-------------------------------
# Accuracy: 80.4%, Avg loss: 0.437817
# Epoch 53-------------------------------
# Accuracy: 80.0%, Avg loss: 0.440200
# Epoch 54-------------------------------
# Accuracy: 79.0%, Avg loss: 0.446820
# Epoch 55-------------------------------
# Accuracy: 80.9%, Avg loss: 0.447847
# Epoch 56-------------------------------
# Accuracy: 80.5%, Avg loss: 0.435294
# Epoch 57-------------------------------
# Accuracy: 81.2%, Avg loss: 0.426895
# Epoch 58-------------------------------
# Accuracy: 80.7%, Avg loss: 0.428426
# Epoch 59-------------------------------
# Accuracy: 77.7%, Avg loss: 0.483328
# Epoch 60-------------------------------
# Accuracy: 80.2%, Avg loss: 0.441413
# Epoch 61-------------------------------
# Accuracy: 80.8%, Avg loss: 0.444023
# Epoch 62-------------------------------
# Accuracy: 81.4%, Avg loss: 0.431763
# Epoch 63-------------------------------
# Accuracy: 80.3%, Avg loss: 0.430609
# Epoch 64-------------------------------
# Accuracy: 81.2%, Avg loss: 0.439385
# Epoch 65-------------------------------
# Accuracy: 80.6%, Avg loss: 0.444810
# Epoch 66-------------------------------
# Accuracy: 79.5%, Avg loss: 0.458426
# Epoch 67-------------------------------
# Accuracy: 79.1%, Avg loss: 0.444818
# Epoch 68-------------------------------
# Accuracy: 80.0%, Avg loss: 0.438270
# Epoch 69-------------------------------
# Accuracy: 80.3%, Avg loss: 0.441926
# Epoch 70-------------------------------
# Accuracy: 78.7%, Avg loss: 0.462546
# Epoch 71-------------------------------
# Accuracy: 81.0%, Avg loss: 0.443894
# Epoch 72-------------------------------
# Accuracy: 79.2%, Avg loss: 0.468327
# Epoch 73-------------------------------
# Accuracy: 81.0%, Avg loss: 0.451148
# Epoch 74-------------------------------
# Accuracy: 81.0%, Avg loss: 0.448415
# Epoch 75-------------------------------
# Accuracy: 79.9%, Avg loss: 0.455214
# Epoch 76-------------------------------
# Accuracy: 81.2%, Avg loss: 0.460508
# Epoch 77-------------------------------
# Accuracy: 79.2%, Avg loss: 0.458590
# Epoch 78-------------------------------
# Accuracy: 78.2%, Avg loss: 0.475708
# Epoch 79-------------------------------
# Accuracy: 79.6%, Avg loss: 0.443207
# Epoch 80-------------------------------
# Accuracy: 81.4%, Avg loss: 0.433810
# Epoch 81-------------------------------
# Accuracy: 81.4%, Avg loss: 0.438904
# Epoch 82-------------------------------
# Accuracy: 79.2%, Avg loss: 0.462933
# Epoch 83-------------------------------
# Accuracy: 79.8%, Avg loss: 0.451439
# Epoch 84-------------------------------
# Accuracy: 82.0%, Avg loss: 0.434035
# Epoch 85-------------------------------
# Accuracy: 81.2%, Avg loss: 0.453541
# Epoch 86-------------------------------
# Accuracy: 78.4%, Avg loss: 0.464304
# Epoch 87-------------------------------
# Accuracy: 80.4%, Avg loss: 0.437842
# Epoch 88-------------------------------
# Accuracy: 79.3%, Avg loss: 0.458900
# Epoch 89-------------------------------
# Accuracy: 81.1%, Avg loss: 0.429859
# Epoch 90-------------------------------
# Accuracy: 81.7%, Avg loss: 0.423554
# Epoch 91-------------------------------
# Accuracy: 79.9%, Avg loss: 0.452458
# Epoch 92-------------------------------
# Accuracy: 80.7%, Avg loss: 0.446265
# Epoch 93-------------------------------
# Accuracy: 81.5%, Avg loss: 0.421159
# Epoch 94-------------------------------
# Accuracy: 82.7%, Avg loss: 0.406535
# Epoch 95-------------------------------
# Accuracy: 79.8%, Avg loss: 0.449701
# Epoch 96-------------------------------
# Accuracy: 78.8%, Avg loss: 0.459745
# Epoch 97-------------------------------
# Accuracy: 79.8%, Avg loss: 0.420289
# Epoch 98-------------------------------
# Accuracy: 79.9%, Avg loss: 0.445198
# Epoch 99-------------------------------
# Accuracy: 79.6%, Avg loss: 0.458374
# Epoch 100-------------------------------
# Accuracy: 80.2%, Avg loss: 0.443792
# Epoch 101-------------------------------
# Accuracy: 81.2%, Avg loss: 0.421125
# Epoch 102-------------------------------
# Accuracy: 82.1%, Avg loss: 0.423792
# Epoch 103-------------------------------
# Accuracy: 81.6%, Avg loss: 0.420379
# Epoch 104-------------------------------
# Accuracy: 80.2%, Avg loss: 0.471012
# Epoch 105-------------------------------
# Accuracy: 79.3%, Avg loss: 0.449399
# Epoch 106-------------------------------
# Accuracy: 82.0%, Avg loss: 0.425229
# Epoch 107-------------------------------
# Accuracy: 80.4%, Avg loss: 0.449504
# Epoch 108-------------------------------
# Accuracy: 80.4%, Avg loss: 0.453041
# Epoch 109-------------------------------
# Accuracy: 79.7%, Avg loss: 0.451746
# Epoch 110-------------------------------
# Accuracy: 80.6%, Avg loss: 0.445354
# Epoch 111-------------------------------
# Accuracy: 79.8%, Avg loss: 0.453441
# Epoch 112-------------------------------
# Accuracy: 78.4%, Avg loss: 0.466022
# Epoch 113-------------------------------
# Accuracy: 80.8%, Avg loss: 0.433013
# Epoch 114-------------------------------
# Accuracy: 79.8%, Avg loss: 0.449253
# Epoch 115-------------------------------
# Accuracy: 81.0%, Avg loss: 0.440395
# Epoch 116-------------------------------
# Accuracy: 79.0%, Avg loss: 0.442591
# Epoch 117-------------------------------
# Accuracy: 81.9%, Avg loss: 0.435789
# Epoch 118-------------------------------
# Accuracy: 81.6%, Avg loss: 0.435654
# Epoch 119-------------------------------
# Accuracy: 81.2%, Avg loss: 0.433021
# Epoch 120-------------------------------
# Accuracy: 79.7%, Avg loss: 0.436263
# Epoch 121-------------------------------
# Accuracy: 80.4%, Avg loss: 0.444617
# Epoch 122-------------------------------
# Accuracy: 81.2%, Avg loss: 0.439945
# Epoch 123-------------------------------
# Accuracy: 80.3%, Avg loss: 0.448607
# Epoch 124-------------------------------
# Accuracy: 79.8%, Avg loss: 0.471519
# Epoch 125-------------------------------
# Accuracy: 80.2%, Avg loss: 0.435139
# Epoch 126-------------------------------
# Accuracy: 79.1%, Avg loss: 0.449646
# Epoch 127-------------------------------
# Accuracy: 81.8%, Avg loss: 0.417353
# Epoch 128-------------------------------
# Accuracy: 79.3%, Avg loss: 0.451400
# Epoch 129-------------------------------
# Accuracy: 80.8%, Avg loss: 0.447514
# Epoch 130-------------------------------
# Accuracy: 79.7%, Avg loss: 0.470167
# Epoch 131-------------------------------
# Accuracy: 80.6%, Avg loss: 0.435134
# Epoch 132-------------------------------
# Accuracy: 79.0%, Avg loss: 0.456931
# Epoch 133-------------------------------
# Accuracy: 82.7%, Avg loss: 0.420995
# Epoch 134-------------------------------
# Accuracy: 81.6%, Avg loss: 0.422427
# Epoch 135-------------------------------
# Accuracy: 82.5%, Avg loss: 0.447306
# Epoch 136-------------------------------
# Accuracy: 82.0%, Avg loss: 0.416432
# Epoch 137-------------------------------
# Accuracy: 81.4%, Avg loss: 0.453308
# Epoch 138-------------------------------
# Accuracy: 81.7%, Avg loss: 0.435878
# Epoch 139-------------------------------
# Accuracy: 80.6%, Avg loss: 0.445115
# Epoch 140-------------------------------
# Accuracy: 82.0%, Avg loss: 0.417736
# Epoch 141-------------------------------
# Accuracy: 82.0%, Avg loss: 0.442606
# Epoch 142-------------------------------
# Accuracy: 80.7%, Avg loss: 0.434053
# Epoch 143-------------------------------
# Accuracy: 82.7%, Avg loss: 0.415673
# Epoch 144-------------------------------
# Accuracy: 80.1%, Avg loss: 0.443266
# Epoch 145-------------------------------
# Accuracy: 80.0%, Avg loss: 0.475368
# Epoch 146-------------------------------
# Accuracy: 80.8%, Avg loss: 0.464584
# Epoch 147-------------------------------
# Accuracy: 79.9%, Avg loss: 0.450177
# Epoch 148-------------------------------
# Accuracy: 81.3%, Avg loss: 0.459975
# Epoch 149-------------------------------
# Accuracy: 81.3%, Avg loss: 0.447849
# Epoch 150-------------------------------
# Accuracy: 80.0%, Avg loss: 0.468118
# 47.48450994491577

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(np.arange(1,epochs+1),train_loss,'b',np.arange(1,epochs+1),test_loss,'r')
plt.legend(["training loss","test loss"])

# %%
import seaborn as sn

model2 = BinaryClassification()
model2.load_state_dict(torch.load('model.pkl'))

classes = [
    "No Inv",
    "Inv"
]

model2.eval()

cm=np.zeros((len(classes),len(classes)))

#test_loader=DataLoader(test_data,sampler=sampler_test,batch_size=1)
xa=[]
xb=[]
xc=[]
xd=[]
for x,y in valid_loader:
  pred = model2(x)
  pred = torch.round(torch.sigmoid(pred))
  x1=pred.detach().numpy().astype(int)
  y1=y.detach().numpy().astype(int)
  cm[x1,y1]+=1
  #print(f'預測值："{pred[0].argmax(0)}" / 實際值："{y[0]}"')

  for n in range(0,y1.shape[0]):
    if x1[n]==y1[n] & y1[n]==0:
      xa.append(x[n,:])
    if x1[n]!=y1[n] & y1[n]==0:
      xb.append(x[n,:])
    if x1[n]!=y1[n] & y1[n]==1:
      xc.append(x[n,:])
    if x1[n]==y1[n] & y1[n]==1:
      xd.append(x[n,:])

plt.rcParams.update({'ytick.major.size':2,'ytick.major.width':0.75})
fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax=sn.heatmap(cm.transpose(),xticklabels=classes,yticklabels=classes,annot=True,cmap='Blues',fmt='g',annot_kws={"fontsize":4})

plt.yticks(rotation=0) 
plt.xticks(rotation=90)
sn.set(font_scale=0.5)
ax.tick_params(labelsize=4) 
ax.figure.axes[-1].tick_params(labelsize=4)
plt.xlabel('Prediction')
plt.ylabel('True')

print('\n\n\n\n\n\n\n')
print('Accuracy is ',np.diagonal(cm).sum()/cm.sum())
print('Precision is ',cm[1,1]/cm[1,:].sum())
print('Recall is ',cm[1,1]/cm[:,1].sum())
print('F1 score is ',2.*(cm[1,1]/cm[:,1].sum()*cm[1,1]/cm[1,:].sum())/(cm[1,1]/cm[:,1].sum()+cm[1,1]/cm[1,:].sum()))
# Out:
# Accuracy is  0.7855626326963907
# Precision is  0.9106047326906223
# Recall is  0.7747949291573453
# F1 score is  0.8372280419016923

# %%
print(len(xa),len(xb),len(xc),len(xd))
p=np.flip(np.array([1000.,975.,950.,925.,900.,875.,850.,825.,800.,775.,750.,700.,650.,600.,550.,500.]),0)
fig,ax=plt.subplots(nrows=4,ncols=2,figsize=(4,8),dpi=300)
ax=ax.flatten()

for i in range(0,8,2):
  print(i)
  ii=i*10+4
  if i==0:
    xdraw=scaler[0].inverse_transform(xa[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xa[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xa[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xa[ii+12][16:32].reshape(-1,16)),0)
  if i==2:
    xdraw=scaler[0].inverse_transform(xb[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xb[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xb[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xb[ii+12][16:32].reshape(-1,16)),0)
  if i==4:
    xdraw=scaler[0].inverse_transform(xc[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xc[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xc[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xc[ii+12][16:32].reshape(-1,16)),0)
  if i==6:
    xdraw=scaler[0].inverse_transform(xd[ii][0:16].reshape(-1,16))
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+20][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+13][0:16].reshape(-1,16)),0)
    xdraw=np.append(xdraw,scaler[0].inverse_transform(xd[ii+12][0:16].reshape(-1,16)),0)
    xdraw2=scaler[1].inverse_transform(xd[ii][16:32].reshape(-1,16))
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+20][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+13][16:32].reshape(-1,16)),0)
    xdraw2=np.append(xdraw2,scaler[1].inverse_transform(xd[ii+12][16:32].reshape(-1,16)),0)
  
  ax[i].plot(xdraw[0,:],p,'b',xdraw[1,:],p,'r',xdraw[2,:],p,'y',xdraw[3,:],p,'k')
  ax[i].set_ylim([1000,500])
  ax[i].set_xlim([300,360])
  ax[i].set_xlabel('theta_e',fontsize=8)
  ax[i].set_ylabel('pressure',fontsize=8)

  ax[i+1].plot(xdraw2[0,:],p,'b',xdraw2[1,:],p,'r',xdraw2[2,:],p,'y',xdraw2[3,:],p,'k')
  ax[i+1].set_ylim([1000,500])
  ax[i+1].set_xlim([0.,0.02])
  ax[i+1].set_xlabel('Qt',fontsize=8)
# Out:
# 441 102 302 1039
# 0
# 2
# 4
# 6

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

valid_loader=DataLoader(dataset=valid_data,batch_size=10000)
for x,y in valid_loader:
  print(x.shape,y.shape)
  pred = model2(x)
  pred = torch.sigmoid(pred)
  x1=pred.detach().numpy()
  y1=y.detach().numpy()

rocx,rocy,_=roc_curve(y1,x1)
roc_area=roc_auc_score(y1,x1)
print(roc_area)

fig,ax=plt.subplots(figsize=(2,2),dpi=300)
ax.plot(rocx,rocy,'r-',[0, 1],[0, 1],'b--')
ax.set_ylim([0,1])
ax.set_xlim([0,1])
ax.set_xlabel('False alarm rate',fontsize=8)
ax.set_ylabel('Hit rate',fontsize=8)
ax.grid(lw=0.5,alpha=0.5)
# Out:
# torch.Size([1884, 32]) torch.Size([1884, 1])
# 0.8635896083706532
